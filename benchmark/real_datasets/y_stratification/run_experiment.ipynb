# %% [markdown]
# # Full scikit-fair benchmark
#
# ## Stratification on target only
#
# Runs the configuration in `config.yaml` through `Experiment.from_config()`.
# All outputs (CSV, pickle, HTML report) are written to
# `../../outputs/real_datasets/y_stratification.{csv,pkl,html}` automatically via
# the `save:` block of the YAML.

# %% [markdown]
# ## The YAML configuration

# %%
with open("config.yaml") as f:
    print(f.read())
# Out:
# # Full scikit-fair preprocessing benchmark.
# #
# # Consumed by Experiment.from_config(): 5 datasets × 12 methods × 4 classifiers
# # under 5-fold CV, every fairness metric plus five performance metrics.
#
# datasets:
#   - name: adult
#   - name: compas
#   - name: german
#   - name: heart_disease
#   - name: ricci
#
# methods:
#   - Baseline
#   - FairSmote
#   - Massaging
#   - FairOversampling
#   - FAWOS
#   - HeterogeneousFOS
#   - FairwayRemover
#   - DisparateImpactRemover
#   - LearningFairRepresentations
#   - ReweighingClassifier
#   - FairBalanceClassifier
#   - FairMask
#
# classifiers:
#   - path: sklearn.linear_model.LogisticRegression
#     name: LogReg
#     solver: liblinear
#     max_iter: 1000
#     random_state: 42
#   - path: sklearn.tree.DecisionTreeClassifier
#     name: DecisionTree
#     random_state: 42
#   - path: sklearn.svm.SVC
#     name: SVC
#     random_state: 42
#   - path: xgboost.XGBClassifier
#     name: XGBoost
#     eval_metric: logloss
#     random_state: 42
#
# cv:
#   n_splits: 5
#   random_state: 42
#   stratify: y
#
#
# metrics:
#   # performance
#   - accuracy
#   - balanced_accuracy
#   - precision
#   - recall
#   - f1_score
#   # fairness
#   - disparate_impact
#   - spd
#   - eod
#   - aod
#   - true_negative_rate_difference
#   - predictive_equality
#   - accuracy_parity
#   - equal_opportunity_ratio
#   - false_negative_rate_difference
#
# audit:
#   bias: true
#   fairness: true
#
# save:
#   results_csv: true    # save results DataFrame to {path}.csv
#   object_pkl: true     # pickle full Experiment to {path}.pkl
#   report_html: true    # generate HTML report to {path}.html
#   path: ../../outputs/real_datasets/y_stratification

# %% [markdown]
# ## Run the experiment
#
# `save.results_csv`, `save.object_pkl`, and `save.report_html` in the YAML are
# all `true`, so results are persisted to
# `../../outputs/real_datasets/y_stratification.{csv,pkl,html}` as soon as
# `run()` completes.
#
#
#
#  -- First experiment - all metrics, all datasets, all models but OPP - simple preprocessing, all defaults

# %%
from pathlib import Path
import yaml
from skfair.experimentation import Experiment

with open("config.yaml") as f:
    _cfg = yaml.safe_load(f)
Path(_cfg["save"]["path"]).parent.mkdir(parents=True, exist_ok=True)

exp = Experiment.from_config("config.yaml")
results = exp.run(verbose=True)
results
# Out:
# ============================================================
# Dataset: Adult
# ============================================================
#   Baseline                       | LogReg  acc=0.851  spd=-0.179
#   Baseline                       | DecisionTree  acc=0.820  spd=-0.179
#   Baseline                       | SVC  acc=0.856  spd=-0.170
#   Baseline                       | XGBoost  acc=0.873  spd=-0.182
#   FairSmote                      | LogReg  acc=0.815  spd=-0.204
#   FairSmote                      | DecisionTree  acc=0.805  spd=-0.171
#   FairSmote                      | SVC  acc=0.822  spd=-0.235
#   FairSmote                      | XGBoost  acc=0.851  spd=-0.214
#   Massaging                      | LogReg  acc=0.829  spd=-0.008
#   Massaging                      | DecisionTree  acc=0.818  spd=0.005
#   Massaging                      | SVC  acc=0.832  spd=-0.023
#   Massaging                      | XGBoost  acc=0.842  spd=-0.014
#   FairOversampling               | LogReg  acc=0.814  spd=-0.197
#   FairOversampling               | DecisionTree  acc=0.808  spd=-0.174
#   FairOversampling               | SVC  acc=0.821  spd=-0.239
#   FairOversampling               | XGBoost  acc=0.852  spd=-0.221
#   FAWOS                          | LogReg  acc=0.846  spd=-0.117
#   FAWOS                          | DecisionTree  acc=0.818  spd=-0.169
#   FAWOS                          | SVC  acc=0.854  spd=-0.119
#   FAWOS                          | XGBoost  acc=0.868  spd=-0.143
#   HeterogeneousFOS               | LogReg  acc=0.803  spd=-0.178
#   HeterogeneousFOS               | DecisionTree  acc=0.800  spd=-0.159
#   HeterogeneousFOS               | SVC  acc=0.833  spd=-0.203
#   HeterogeneousFOS               | XGBoost  acc=0.861  spd=-0.184
#   FairwayRemover                 | LogReg  acc=0.851  spd=-0.180
#   FairwayRemover                 | DecisionTree  acc=0.820  spd=-0.178
#   FairwayRemover                 | SVC  acc=0.855  spd=-0.168
#   FairwayRemover                 | XGBoost  acc=0.871  spd=-0.184
#   DisparateImpactRemover         | LogReg  acc=0.852  spd=-0.173
#   DisparateImpactRemover         | DecisionTree  acc=0.817  spd=-0.177
#   DisparateImpactRemover         | SVC  acc=0.857  spd=-0.162
#   DisparateImpactRemover         | XGBoost  acc=0.870  spd=-0.182
#   LearningFairRepresentations    | LogReg  acc=0.840  spd=-0.182
#   LearningFairRepresentations    | DecisionTree  acc=0.796  spd=-0.173
#   LearningFairRepresentations    | SVC  acc=0.831  spd=-0.179
#   LearningFairRepresentations    | XGBoost  acc=0.851  spd=-0.179
#   ReweighingClassifier           | LogReg  acc=0.846  spd=-0.084
#   ReweighingClassifier           | DecisionTree  acc=0.820  spd=-0.170
#   ReweighingClassifier           | SVC  acc=0.849  spd=-0.067
#   ReweighingClassifier           | XGBoost  acc=0.868  spd=-0.107
#   FairBalanceClassifier          | LogReg  acc=0.814  spd=-0.188
#   FairBalanceClassifier          | DecisionTree  acc=0.814  spd=-0.210
#   FairBalanceClassifier          | SVC  acc=0.815  spd=-0.221
#   FairBalanceClassifier          | XGBoost  acc=0.840  spd=-0.212
#   FairMask                       | LogReg  acc=0.851  spd=-0.174
#   FairMask                       | DecisionTree  acc=0.822  spd=-0.173
#   FairMask                       | SVC  acc=0.856  spd=-0.169
#   FairMask                       | XGBoost  acc=0.872  spd=-0.178
#
# ============================================================
# Dataset: Compas
# ============================================================
#   Baseline                       | LogReg  acc=0.676  spd=-0.280
#   Baseline                       | DecisionTree  acc=0.620  spd=-0.096
#   Baseline                       | SVC  acc=0.673  spd=-0.185
#   Baseline                       | XGBoost  acc=0.665  spd=-0.176
#   FairSmote                      | LogReg  acc=0.665  spd=-0.012
#   FairSmote                      | DecisionTree  acc=0.612  spd=-0.033
#   FairSmote                      | SVC  acc=0.670  spd=-0.092
#   FairSmote                      | XGBoost  acc=0.653  spd=-0.107
#   Massaging                      | LogReg  acc=0.667  spd=0.022
#   Massaging                      | DecisionTree  acc=0.630  spd=0.022
#   Massaging                      | SVC  acc=0.673  spd=-0.061
#   Massaging                      | XGBoost  acc=0.659  spd=-0.058
#   FairOversampling               | LogReg  acc=0.667  spd=-0.000
#   FairOversampling               | DecisionTree  acc=0.620  spd=-0.085
#   FairOversampling               | SVC  acc=0.675  spd=-0.078
#   FairOversampling               | XGBoost  acc=0.653  spd=-0.092
#   FAWOS                          | LogReg  acc=0.672  spd=-0.010
#   FAWOS                          | DecisionTree  acc=0.619  spd=-0.051
#   FAWOS                          | SVC  acc=0.676  spd=-0.083
#   FAWOS                          | XGBoost  acc=0.657  spd=-0.071
#   HeterogeneousFOS               | LogReg  acc=0.668  spd=-0.002
#   HeterogeneousFOS               | DecisionTree  acc=0.615  spd=-0.012
#   HeterogeneousFOS               | SVC  acc=0.670  spd=-0.118
#   HeterogeneousFOS               | XGBoost  acc=0.649  spd=-0.056
#   FairwayRemover                 | LogReg  acc=0.668  spd=-0.230
#   FairwayRemover                 | DecisionTree  acc=0.616  spd=-0.087
#   FairwayRemover                 | SVC  acc=0.666  spd=-0.161
#   FairwayRemover                 | XGBoost  acc=0.659  spd=-0.146
#   DisparateImpactRemover         | LogReg  acc=0.679  spd=-0.248
#   DisparateImpactRemover         | DecisionTree  acc=0.619  spd=-0.103
#   DisparateImpactRemover         | SVC  acc=0.674  spd=-0.202
#   DisparateImpactRemover         | XGBoost  acc=0.659  spd=-0.159
#   LearningFairRepresentations    | LogReg  acc=0.601  spd=-0.391
#   LearningFairRepresentations    | DecisionTree  acc=0.616  spd=-0.121
#   LearningFairRepresentations    | SVC  acc=0.591  spd=-0.448
#   LearningFairRepresentations    | XGBoost  acc=0.644  spd=-0.163
#   ReweighingClassifier           | LogReg  acc=0.671  spd=-0.015
#   ReweighingClassifier           | DecisionTree  acc=0.617  spd=0.009
#   ReweighingClassifier           | SVC  acc=0.673  spd=-0.092
#   ReweighingClassifier           | XGBoost  acc=0.661  spd=-0.059
#   FairBalanceClassifier          | LogReg  acc=0.664  spd=0.009
#   FairBalanceClassifier          | DecisionTree  acc=0.602  spd=-0.094
#   FairBalanceClassifier          | SVC  acc=0.670  spd=-0.097
#   FairBalanceClassifier          | XGBoost  acc=0.657  spd=-0.067
#   FairMask                       | LogReg  acc=0.666  spd=-0.140
#   FairMask                       | DecisionTree  acc=0.614  spd=-0.072
#   FairMask                       | SVC  acc=0.669  spd=-0.144
#   FairMask                       | XGBoost  acc=0.660  spd=-0.119
#
# ============================================================
# Dataset: German
# ============================================================
#   Baseline                       | LogReg  acc=0.752  spd=-0.102
#   Baseline                       | DecisionTree  acc=0.668  spd=-0.073
#   Baseline                       | SVC  acc=0.738  spd=-0.043
#   Baseline                       | XGBoost  acc=0.733  spd=-0.048
#   FairSmote                      | LogReg  acc=0.707  spd=-0.024
#   FairSmote                      | DecisionTree  acc=0.643  spd=0.017
#   FairSmote                      | SVC  acc=0.694  spd=-0.009
#   FairSmote                      | XGBoost  acc=0.715  spd=-0.013
#   Massaging                      | LogReg  acc=0.734  spd=0.014
#   Massaging                      | DecisionTree  acc=0.699  spd=-0.018
#   Massaging                      | SVC  acc=0.744  spd=-0.029
#   Massaging                      | XGBoost  acc=0.756  spd=0.001
#   FairOversampling               | LogReg  acc=0.721  spd=-0.029
#   FairOversampling               | DecisionTree  acc=0.634  spd=-0.004
#   FairOversampling               | SVC  acc=0.722  spd=-0.048
#   FairOversampling               | XGBoost  acc=0.731  spd=-0.052
#   FAWOS                          | LogReg  acc=0.747  spd=-0.013
#   FAWOS                          | DecisionTree  acc=0.687  spd=-0.044
#   FAWOS                          | SVC  acc=0.744  spd=-0.016
#   FAWOS                          | XGBoost  acc=0.739  spd=-0.053
#   HeterogeneousFOS               | LogReg  acc=0.676  spd=-0.026
#   HeterogeneousFOS               | DecisionTree  acc=0.632  spd=-0.030
#   HeterogeneousFOS               | SVC  acc=0.689  spd=0.007
#   HeterogeneousFOS               | XGBoost  acc=0.716  spd=0.023
#   FairwayRemover                 | LogReg  acc=0.743  spd=-0.003
#   FairwayRemover                 | DecisionTree  acc=0.665  spd=-0.081
#   FairwayRemover                 | SVC  acc=0.737  spd=0.002
#   FairwayRemover                 | XGBoost  acc=0.739  spd=0.008
#   DisparateImpactRemover         | LogReg  acc=0.750  spd=-0.125
#   DisparateImpactRemover         | DecisionTree  acc=0.671  spd=-0.123
#   DisparateImpactRemover         | SVC  acc=0.754  spd=-0.109
#   DisparateImpactRemover         | XGBoost  acc=0.747  spd=-0.057
#   LearningFairRepresentations    | LogReg  acc=0.734  spd=-0.107
#   LearningFairRepresentations    | DecisionTree  acc=0.660  spd=-0.033
#   LearningFairRepresentations    | SVC  acc=0.738  spd=-0.084
#   LearningFairRepresentations    | XGBoost  acc=0.708  spd=-0.068
#   ReweighingClassifier           | LogReg  acc=0.746  spd=-0.011
#   ReweighingClassifier           | DecisionTree  acc=0.682  spd=-0.018
#   ReweighingClassifier           | SVC  acc=0.742  spd=-0.012
#   ReweighingClassifier           | XGBoost  acc=0.751  spd=-0.031
#   FairBalanceClassifier          | LogReg  acc=0.711  spd=-0.027
#   FairBalanceClassifier          | DecisionTree  acc=0.686  spd=-0.017
#   FairBalanceClassifier          | SVC  acc=0.711  spd=-0.045
#   FairBalanceClassifier          | XGBoost  acc=0.740  spd=-0.045
#   FairMask                       | LogReg  acc=0.739  spd=-0.025
#   FairMask                       | DecisionTree  acc=0.660  spd=-0.041
#   FairMask                       | SVC  acc=0.727  spd=0.018
#   FairMask                       | XGBoost  acc=0.735  spd=-0.009
#
# ============================================================
# Dataset: Heart Disease
# ============================================================
#   Baseline                       | LogReg  acc=0.841  spd=0.346
#   Baseline                       | DecisionTree  acc=0.696  spd=0.122
#   Baseline                       | SVC  acc=0.830  spd=0.331
#   Baseline                       | XGBoost  acc=0.800  spd=0.331
#   FairSmote                      | LogReg  acc=0.807  spd=0.269
#   FairSmote                      | DecisionTree  acc=0.730  spd=0.169
#   FairSmote                      | SVC  acc=0.822  spd=0.258
#   FairSmote                      | XGBoost  acc=0.800  spd=0.311
#   Massaging                      | LogReg  acc=0.841  spd=0.346
#   Massaging                      | DecisionTree  acc=0.696  spd=0.122
#   Massaging                      | SVC  acc=0.830  spd=0.331
#   Massaging                      | XGBoost  acc=0.800  spd=0.331
#   FairOversampling               | LogReg  acc=0.830  spd=0.268
#   FairOversampling               | DecisionTree  acc=0.759  spd=0.235
#   FairOversampling               | SVC  acc=0.815  spd=0.266
#   FairOversampling               | XGBoost  acc=0.789  spd=0.339
#   FAWOS                          | LogReg  acc=0.841  spd=0.346
#   FAWOS                          | DecisionTree  acc=0.696  spd=0.122
#   FAWOS                          | SVC  acc=0.830  spd=0.331
#   FAWOS                          | XGBoost  acc=0.800  spd=0.331
#   HeterogeneousFOS               | LogReg  acc=0.811  spd=0.260
#   HeterogeneousFOS               | DecisionTree  acc=0.752  spd=0.203
#   HeterogeneousFOS               | SVC  acc=0.822  spd=0.254
#   HeterogeneousFOS               | XGBoost  acc=0.781  spd=0.350
#   FairwayRemover                 | LogReg  acc=0.804  spd=0.299
#   FairwayRemover                 | DecisionTree  acc=0.733  spd=0.293
#   FairwayRemover                 | SVC  acc=0.815  spd=0.288
#   FairwayRemover                 | XGBoost  acc=0.785  spd=0.282
#   DisparateImpactRemover         | LogReg  acc=0.837  spd=0.344
#   DisparateImpactRemover         | DecisionTree  acc=0.744  spd=0.227
#   DisparateImpactRemover         | SVC  acc=0.819  spd=0.351
#   DisparateImpactRemover         | XGBoost  acc=0.811  spd=0.366
#   LearningFairRepresentations    | LogReg  acc=0.707  spd=0.718
#   LearningFairRepresentations    | DecisionTree  acc=0.641  spd=0.255
#   LearningFairRepresentations    | SVC  acc=0.763  spd=0.559
#   LearningFairRepresentations    | XGBoost  acc=0.741  spd=0.386
#   ReweighingClassifier           | LogReg  acc=0.830  spd=0.277
#   ReweighingClassifier           | DecisionTree  acc=0.722  spd=0.205
#   ReweighingClassifier           | SVC  acc=0.841  spd=0.267
#   ReweighingClassifier           | XGBoost  acc=0.785  spd=0.286
#   FairBalanceClassifier          | LogReg  acc=0.826  spd=0.286
#   FairBalanceClassifier          | DecisionTree  acc=0.737  spd=0.198
#   FairBalanceClassifier          | SVC  acc=0.811  spd=0.271
#   FairBalanceClassifier          | XGBoost  acc=0.789  spd=0.292
#   FairMask                       | LogReg  acc=0.833  spd=0.311
#   FairMask                       | DecisionTree  acc=0.693  spd=0.100
#   FairMask                       | SVC  acc=0.830  spd=0.317
#   FairMask                       | XGBoost  acc=0.785  spd=0.271
#
# ============================================================
# Dataset: Ricci
# ============================================================
#   Baseline                       | LogReg  acc=0.812  spd=-0.509
#   Baseline                       | DecisionTree  acc=0.931  spd=-0.304
#   Baseline                       | SVC  acc=0.914  spd=-0.369
#   Baseline                       | XGBoost  acc=0.940  spd=-0.316
#   FairSmote                      | LogReg  acc=0.830  spd=-0.125
#   FairSmote                      | DecisionTree  acc=0.889  spd=-0.333
#   FairSmote                      | SVC  acc=0.923  spd=-0.339
#   FairSmote                      | XGBoost  acc=0.889  spd=-0.288
#   Massaging                      | LogReg  acc=0.685  spd=0.004
#   Massaging                      | DecisionTree  acc=0.821  spd=-0.066
#   Massaging                      | SVC  acc=0.863  spd=-0.377
#   Massaging                      | XGBoost  acc=0.813  spd=-0.011
#   FairOversampling               | LogReg  acc=0.787  spd=-0.162
#   FairOversampling               | DecisionTree  acc=0.940  spd=-0.286
#   FairOversampling               | SVC  acc=0.889  spd=-0.333
#   FairOversampling               | XGBoost  acc=0.940  spd=-0.316
#   FAWOS                          | LogReg  acc=0.771  spd=-0.144
#   FAWOS                          | DecisionTree  acc=0.931  spd=-0.306
#   FAWOS                          | SVC  acc=0.872  spd=-0.390
#   FAWOS                          | XGBoost  acc=0.932  spd=-0.338
#   HeterogeneousFOS               | LogReg  acc=0.864  spd=-0.128
#   HeterogeneousFOS               | DecisionTree  acc=0.924  spd=-0.371
#   HeterogeneousFOS               | SVC  acc=0.932  spd=-0.359
#   HeterogeneousFOS               | XGBoost  acc=0.940  spd=-0.355
#   FairwayRemover                 | LogReg  acc=0.525  spd=-0.045
# /home/joao/Desktop/scikit-fair/skfair/experimentation/_runner.py:252: RuntimeWarning: No predicted positives; precision is undefined, returning 0.0.
#   fold_metrics[name].append(fn(y_test, y_pred))
# /home/joao/Desktop/scikit-fair/skfair/metrics/_performance.py:236: RuntimeWarning: No predicted positives; precision is undefined, returning 0.0.
#   p = precision(y_true, y_pred)
#   FairwayRemover                 | DecisionTree  acc=0.762  spd=-0.281
#   FairwayRemover                 | SVC  acc=0.652  spd=-0.176
# /home/joao/Desktop/scikit-fair/skfair/experimentation/_runner.py:252: RuntimeWarning: No predicted positives; precision is undefined, returning 0.0.
#   fold_metrics[name].append(fn(y_test, y_pred))
# /home/joao/Desktop/scikit-fair/skfair/metrics/_performance.py:236: RuntimeWarning: No predicted positives; precision is undefined, returning 0.0.
#   p = precision(y_true, y_pred)
# /home/joao/Desktop/scikit-fair/skfair/experimentation/_runner.py:252: RuntimeWarning: No predicted positives; precision is undefined, returning 0.0.
#   fold_metrics[name].append(fn(y_test, y_pred))
# /home/joao/Desktop/scikit-fair/skfair/metrics/_performance.py:236: RuntimeWarning: No predicted positives; precision is undefined, returning 0.0.
#   p = precision(y_true, y_pred)
#   FairwayRemover                 | XGBoost  acc=0.678  spd=-0.248
#   DisparateImpactRemover         | LogReg  acc=0.787  spd=-0.590
#   DisparateImpactRemover         | DecisionTree  acc=0.881  spd=-0.244
#   DisparateImpactRemover         | SVC  acc=0.830  spd=0.023
#   DisparateImpactRemover         | XGBoost  acc=0.839  spd=-0.334
#   LearningFairRepresentations    | LogReg  acc=0.754  spd=-0.574
#   LearningFairRepresentations    | DecisionTree  acc=0.804  spd=-0.400
# /home/joao/Desktop/scikit-fair/skfair/experimentation/_runner.py:252: RuntimeWarning: No predicted positives; precision is undefined, returning 0.0.
#   fold_metrics[name].append(fn(y_test, y_pred))
# /home/joao/Desktop/scikit-fair/skfair/metrics/_performance.py:236: RuntimeWarning: No predicted positives; precision is undefined, returning 0.0.
#   p = precision(y_true, y_pred)
#   LearningFairRepresentations    | SVC  acc=0.685  spd=-0.186
#   LearningFairRepresentations    | XGBoost  acc=0.821  spd=-0.370
#   ReweighingClassifier           | LogReg  acc=0.796  spd=-0.064
#   ReweighingClassifier           | DecisionTree  acc=0.940  spd=-0.315
#   ReweighingClassifier           | SVC  acc=0.914  spd=-0.369
#   ReweighingClassifier           | XGBoost  acc=0.932  spd=-0.338
#   FairBalanceClassifier          | LogReg  acc=0.864  spd=-0.139
#   FairBalanceClassifier          | DecisionTree  acc=0.923  spd=-0.315
#   FairBalanceClassifier          | SVC  acc=0.931  spd=-0.366
#   FairBalanceClassifier          | XGBoost  acc=0.940  spd=-0.355
#   FairMask                       | LogReg  acc=0.862  spd=-0.403
#   FairMask                       | DecisionTree  acc=0.931  spd=-0.304
#   FairMask                       | SVC  acc=0.914  spd=-0.369
#   FairMask                       | XGBoost  acc=0.940  spd=-0.316
#     dataset                 method    classifier  accuracy  balanced_accuracy  \
# 0     Adult               Baseline        LogReg  0.850619           0.764552
# 1     Adult               Baseline  DecisionTree  0.819999           0.748088
# 2     Adult               Baseline           SVC  0.856362           0.764154
# 3     Adult               Baseline       XGBoost  0.872670           0.801584
# 4     Adult              FairSmote        LogReg  0.815239           0.813485
# ..      ...                    ...           ...       ...                ...
# 235   Ricci  FairBalanceClassifier       XGBoost  0.940217           0.940793
# 236   Ricci               FairMask        LogReg  0.862319           0.863403
# 237   Ricci               FairMask  DecisionTree  0.931159           0.930944
# 238   Ricci               FairMask           SVC  0.914493           0.914918
# 239   Ricci               FairMask       XGBoost  0.940217           0.940035
#
#      precision    recall  f1_score  disparate_impact       spd       eod  \
# 0     0.732426  0.598521  0.658625          0.300934 -0.179067 -0.102436
# 1     0.630973  0.609363  0.619847          0.387606 -0.178662 -0.069076
# 2     0.762449  0.586277  0.662819          0.294664 -0.170487 -0.095764
# 3     0.774787  0.664455  0.715371          0.318297 -0.181867 -0.080623
# 4     0.583885  0.810101  0.678632          0.491913 -0.204113  0.029971
# ..         ...       ...       ...               ...       ...       ...
# 235   0.933333  0.946970  0.939027          0.470476 -0.354643 -0.046429
# 236   0.833100  0.890909  0.860775          0.429192 -0.402547 -0.101190
# 237   0.927273  0.927273  0.927273          0.522056 -0.303702  0.107143
# 238   0.896434  0.927273  0.910464          0.440101 -0.369213 -0.079762
# 239   0.933100  0.945455  0.938207          0.509113 -0.315754  0.078571
#
#           aod  true_negative_rate_difference  predictive_equality  \
# 0   -0.088622                       0.074809             0.240888
# 1   -0.078455                       0.087834             0.403638
# 2   -0.080651                       0.065539             0.215667
# 3   -0.072374                       0.064125             0.257236
# 4   -0.037315                       0.104600             0.532905
# ..        ...                            ...                  ...
# 235 -0.101548                       0.156667             0.400000
# 236 -0.182143                       0.263095             0.083333
# 237 -0.029762                       0.166667             0.400000
# 238 -0.121429                       0.163095             0.000000
# 239 -0.039048                       0.156667             0.400000
#
#      accuracy_parity  equal_opportunity_ratio  false_negative_rate_difference
# 0           1.137607                 0.833905                        0.102436
# 1           1.148924                 0.888115                        0.069076
# 2           1.134058                 0.841388                        0.095764
# 3           1.112827                 0.880935                        0.080623
# 4           1.115635                 1.037330                       -0.029971
# ..               ...                      ...                             ...
# 235         1.086840                 0.961905                        0.046429
# 236         1.115354                 0.895714                        0.101190
# 237         1.168889                 1.137143                       -0.107143
# 238         1.060808                 0.919048                        0.079762
# 239         1.132468                 1.090476                       -0.078571
#
# [240 rows x 17 columns]

# %% [markdown]
# ## Summary tables
#
# `to_report()` wraps the results in a `ComparisonReport`. `summary_tables()`
# returns one DataFrame per metric, averaged over classifiers by default.

# %%
report = exp.to_report()
tables = report.summary_tables()
for name, df in tables.items():
    print(f"--- {name} ---")
    display(df)
# Out:
# --- Adult ---
#                              accuracy  balanced_accuracy  precision  recall  \
# method
# Baseline                       0.8499             0.7696     0.7252  0.6147
# DisparateImpactRemover         0.8491             0.7674     0.7256  0.6096
# FAWOS                          0.8464             0.7747     0.7007  0.6364
# FairBalanceClassifier          0.8207             0.8078     0.5986  0.7830
# FairMask                       0.8502             0.7688     0.7273  0.6119
# FairOversampling               0.8242             0.8057     0.6076  0.7700
# FairSmote                      0.8232             0.8061     0.6046  0.7731
# FairwayRemover                 0.8492             0.7672     0.7261  0.6090
# HeterogeneousFOS               0.8242             0.7957     0.6162  0.7408
# LearningFairRepresentations    0.8296             0.7381     0.6802  0.5617
# Massaging                      0.8304             0.7628     0.6527  0.6323
# ReweighingClassifier           0.8458             0.7562     0.7298  0.5833
#
#                              f1_score  disparate_impact     spd     eod  \
# method
# Baseline                       0.6642            0.3254 -0.1775 -0.0870
# DisparateImpactRemover         0.6613            0.3326 -0.1737 -0.0765
# FAWOS                          0.6666            0.4844 -0.1372  0.0571
# FairBalanceClassifier          0.6763            0.4546 -0.2078 -0.0031
# FairMask                       0.6635            0.3334 -0.1735 -0.0796
# FairOversampling               0.6775            0.4448 -0.2078 -0.0068
# FairSmote                      0.6773            0.4534 -0.2060  0.0047
# FairwayRemover                 0.6609            0.3199 -0.1774 -0.0895
# HeterogeneousFOS               0.6699            0.4804 -0.1811  0.0109
# LearningFairRepresentations    0.6143            0.3094 -0.1782 -0.1144
# Massaging                      0.6422            0.9587 -0.0100  0.2778
# ReweighingClassifier           0.6460            0.5485 -0.1070  0.1147
#
#                                 aod  true_negative_rate_difference  \
# method
# Baseline                    -0.0800                         0.0731
# DisparateImpactRemover      -0.0739                         0.0712
# FAWOS                        0.0057                         0.0456
# FairBalanceClassifier       -0.0546                         0.1062
# FairMask                    -0.0746                         0.0697
# FairOversampling            -0.0567                         0.1065
# FairSmote                   -0.0506                         0.1060
# FairwayRemover              -0.0816                         0.0737
# HeterogeneousFOS            -0.0354                         0.0816
# LearningFairRepresentations -0.0994                         0.0844
# Massaging                    0.1725                        -0.0671
# ReweighingClassifier         0.0437                         0.0272
#
#                              predictive_equality  accuracy_parity  \
# method
# Baseline                                  0.2794           1.1334
# DisparateImpactRemover                    0.2891           1.1348
# FAWOS                                     0.5837           1.1226
# FairBalanceClassifier                     0.4836           1.1218
# FairMask                                  0.2950           1.1320
# FairOversampling                          0.4641           1.1264
# FairSmote                                 0.4738           1.1269
# FairwayRemover                            0.2676           1.1353
# HeterogeneousFOS                          0.5334           1.1127
# LearningFairRepresentations               0.2717           1.1553
# Massaging                                 1.8473           1.0432
# ReweighingClassifier                      0.7622           1.1311
#
#                              equal_opportunity_ratio  \
# method
# Baseline                                      0.8611
# DisparateImpactRemover                        0.8771
# FAWOS                                         1.0919
# FairBalanceClassifier                         0.9902
# FairMask                                      0.8722
# FairOversampling                              0.9908
# FairSmote                                     1.0083
# FairwayRemover                                0.8556
# HeterogeneousFOS                              1.0114
# LearningFairRepresentations                   0.8018
# Massaging                                     1.4735
# ReweighingClassifier                          1.2151
#
#                              false_negative_rate_difference
# method
# Baseline                                             0.0870
# DisparateImpactRemover                               0.0765
# FAWOS                                               -0.0571
# FairBalanceClassifier                                0.0031
# FairMask                                             0.0796
# FairOversampling                                     0.0068
# FairSmote                                           -0.0047
# FairwayRemover                                       0.0895
# HeterogeneousFOS                                    -0.0109
# LearningFairRepresentations                          0.1144
# Massaging                                           -0.2778
# ReweighingClassifier                                -0.1147
# --- Compas ---
#                              accuracy  balanced_accuracy  precision  recall  \
# method
# Baseline                       0.6586             0.6459     0.6540  0.5166
# DisparateImpactRemover         0.6579             0.6456     0.6504  0.5218
# FAWOS                          0.6559             0.6460     0.6381  0.5460
# FairBalanceClassifier          0.6483             0.6452     0.6099  0.6137
# FairMask                       0.6522             0.6371     0.6567  0.4839
# FairOversampling               0.6537             0.6480     0.6214  0.5897
# FairSmote                      0.6503             0.6449     0.6166  0.5904
# FairwayRemover                 0.6524             0.6365     0.6608  0.4757
# HeterogeneousFOS               0.6506             0.6450     0.6174  0.5883
# LearningFairRepresentations    0.6129             0.6013     0.5853  0.4839
# Massaging                      0.6573             0.6477     0.6390  0.5509
# ReweighingClassifier           0.6555             0.6424     0.6520  0.5100
#
#                              f1_score  disparate_impact     spd     eod  \
# method
# Baseline                       0.5767            0.5331 -0.1845 -0.1851
# DisparateImpactRemover         0.5785            0.5545 -0.1778 -0.1826
# FAWOS                          0.5880            0.8639 -0.0539 -0.0309
# FairBalanceClassifier          0.6113            0.8660 -0.0620 -0.0369
# FairMask                       0.5564            0.6639 -0.1187 -0.0983
# FairOversampling               0.6040            0.8502 -0.0638 -0.0370
# FairSmote                      0.6026            0.8637 -0.0610 -0.0430
# FairwayRemover                 0.5517            0.5557 -0.1563 -0.1558
# HeterogeneousFOS               0.6020            0.8958 -0.0471 -0.0300
# LearningFairRepresentations    0.5294            0.3622 -0.2807 -0.3065
# Massaging                      0.5911            0.9543 -0.0186  0.0179
# ReweighingClassifier           0.5717            0.8909 -0.0395 -0.0100
#
#                                 aod  true_negative_rate_difference  \
# method
# Baseline                    -0.1570                         0.1289
# DisparateImpactRemover      -0.1514                         0.1201
# FAWOS                       -0.0214                         0.0119
# FairBalanceClassifier       -0.0290                         0.0211
# FairMask                    -0.0889                         0.0795
# FairOversampling            -0.0298                         0.0227
# FairSmote                   -0.0296                         0.0162
# FairwayRemover              -0.1301                         0.1044
# HeterogeneousFOS            -0.0157                         0.0014
# LearningFairRepresentations -0.2680                         0.2296
# Massaging                    0.0173                        -0.0167
# ReweighingClassifier        -0.0062                         0.0024
#
#                              predictive_equality  accuracy_parity  \
# method
# Baseline                                  0.4928           1.0595
# DisparateImpactRemover                    0.5337           1.0502
# FAWOS                                     0.9600           1.0292
# FairBalanceClassifier                     0.9439           1.0091
# FairMask                                  0.6459           1.0737
# FairOversampling                          0.9229           1.0202
# FairSmote                                 0.9510           1.0087
# FairwayRemover                            0.5280           1.0644
# HeterogeneousFOS                          1.0052           1.0042
# LearningFairRepresentations               0.3542           1.0900
# Massaging                                 1.0686           1.0299
# ReweighingClassifier                      0.9932           1.0426
#
#                              equal_opportunity_ratio  \
# method
# Baseline                                      0.6671
# DisparateImpactRemover                        0.6725
# FAWOS                                         0.9425
# FairBalanceClassifier                         0.9383
# FairMask                                      0.8033
# FairOversampling                              0.9335
# FairSmote                                     0.9288
# FairwayRemover                                0.6858
# HeterogeneousFOS                              0.9522
# LearningFairRepresentations                   0.4283
# Massaging                                     1.0383
# ReweighingClassifier                          0.9816
#
#                              false_negative_rate_difference
# method
# Baseline                                             0.1851
# DisparateImpactRemover                               0.1826
# FAWOS                                                0.0309
# FairBalanceClassifier                                0.0369
# FairMask                                             0.0983
# FairOversampling                                     0.0370
# FairSmote                                            0.0430
# FairwayRemover                                       0.1558
# HeterogeneousFOS                                     0.0300
# LearningFairRepresentations                          0.3065
# Massaging                                           -0.0179
# ReweighingClassifier                                 0.0100
# --- German ---
#                              accuracy  balanced_accuracy  precision  recall  \
# method
# Baseline                       0.7228             0.6370     0.7754  0.8514
# DisparateImpactRemover         0.7305             0.6470     0.7806  0.8557
# FAWOS                          0.7292             0.6390     0.7758  0.8646
# FairBalanceClassifier          0.7120             0.6745     0.8123  0.7682
# FairMask                       0.7152             0.6271     0.7701  0.8475
# FairOversampling               0.7020             0.6740     0.8148  0.7439
# FairSmote                      0.6898             0.6634     0.8101  0.7293
# FairwayRemover                 0.7210             0.6324     0.7720  0.8539
# HeterogeneousFOS               0.6782             0.6490     0.8025  0.7221
# LearningFairRepresentations    0.7100             0.6160     0.7623  0.8511
# Massaging                      0.7332             0.6597     0.7909  0.8436
# ReweighingClassifier           0.7303             0.6442     0.7793  0.8593
#
#                              f1_score  disparate_impact     spd     eod  \
# method
# Baseline                       0.8100            0.9161 -0.0664 -0.0415
# DisparateImpactRemover         0.8152            0.8711 -0.1036 -0.0748
# FAWOS                          0.8161            0.9597 -0.0313 -0.0179
# FairBalanceClassifier          0.7883            0.9520 -0.0335  0.0037
# FairMask                       0.8052            0.9801 -0.0143 -0.0004
# FairOversampling               0.7768            0.9506 -0.0333 -0.0124
# FairSmote                      0.7666            0.9895 -0.0073  0.0285
# FairwayRemover                 0.8094            0.9747 -0.0186 -0.0010
# HeterogeneousFOS               0.7574            0.9889 -0.0065  0.0347
# LearningFairRepresentations    0.8033            0.9128 -0.0728 -0.0406
# Massaging                      0.8150            0.9915 -0.0081  0.0045
# ReweighingClassifier           0.8157            0.9795 -0.0179 -0.0024
#
#                                 aod  true_negative_rate_difference  \
# method
# Baseline                    -0.0489                         0.0563
# DisparateImpactRemover      -0.0848                         0.0948
# FAWOS                       -0.0052                        -0.0074
# FairBalanceClassifier       -0.0143                         0.0323
# FairMask                     0.0080                        -0.0164
# FairOversampling            -0.0047                        -0.0029
# FairSmote                    0.0093                         0.0098
# FairwayRemover               0.0022                        -0.0055
# HeterogeneousFOS             0.0071                         0.0205
# LearningFairRepresentations -0.0621                         0.0836
# Massaging                    0.0227                        -0.0409
# ReweighingClassifier         0.0071                        -0.0167
#
#                              predictive_equality  accuracy_parity  \
# method
# Baseline                                  0.9228           0.9428
# DisparateImpactRemover                    0.8682           0.9330
# FAWOS                                     1.0366           0.9356
# FairBalanceClassifier                     0.9357           1.0008
# FairMask                                  1.0361           0.9459
# FairOversampling                          1.0264           0.9767
# FairSmote                                 0.9899           1.0232
# FairwayRemover                            1.0233           0.9520
# HeterogeneousFOS                          0.9477           1.0341
# LearningFairRepresentations               0.8812           0.9524
# Massaging                                 1.1433           0.9497
# ReweighingClassifier                      1.0532           0.9480
#
#                              equal_opportunity_ratio  \
# method
# Baseline                                      0.9497
# DisparateImpactRemover                        0.9136
# FAWOS                                         0.9766
# FairBalanceClassifier                         1.0072
# FairMask                                      0.9972
# FairOversampling                              0.9862
# FairSmote                                     1.0435
# FairwayRemover                                0.9966
# HeterogeneousFOS                              1.0515
# LearningFairRepresentations                   0.9553
# Massaging                                     1.0057
# ReweighingClassifier                          0.9973
#
#                              false_negative_rate_difference
# method
# Baseline                                             0.0415
# DisparateImpactRemover                               0.0748
# FAWOS                                                0.0179
# FairBalanceClassifier                               -0.0037
# FairMask                                             0.0004
# FairOversampling                                     0.0124
# FairSmote                                           -0.0285
# FairwayRemover                                       0.0010
# HeterogeneousFOS                                    -0.0347
# LearningFairRepresentations                          0.0406
# Massaging                                           -0.0045
# ReweighingClassifier                                 0.0024
# --- Heart Disease ---
#                              accuracy  balanced_accuracy  precision  recall  \
# method
# Baseline                       0.7917             0.7867     0.8031  0.8317
# DisparateImpactRemover         0.8028             0.7979     0.8135  0.8417
# FAWOS                          0.7917             0.7867     0.8031  0.8317
# FairBalanceClassifier          0.7907             0.7856     0.8028  0.8317
# FairMask                       0.7852             0.7802     0.7968  0.8250
# FairOversampling               0.7981             0.7960     0.8245  0.8150
# FairSmote                      0.7898             0.7871     0.8123  0.8117
# FairwayRemover                 0.7843             0.7808     0.8052  0.8117
# HeterogeneousFOS               0.7917             0.7879     0.8089  0.8217
# LearningFairRepresentations    0.7130             0.7081     0.7411  0.7517
# Massaging                      0.7917             0.7867     0.8031  0.8317
# ReweighingClassifier           0.7944             0.7890     0.8034  0.8383
#
#                              f1_score  disparate_impact     spd     eod  \
# method
# Baseline                       0.8152            1.6286  0.2825  0.1487
# DisparateImpactRemover         0.8259            1.7286  0.3222  0.1749
# FAWOS                          0.8152            1.6286  0.2825  0.1487
# FairBalanceClassifier          0.8151            1.5711  0.2619  0.1241
# FairMask                       0.8087            1.5283  0.2498  0.1179
# FairOversampling               0.8166            1.6562  0.2772  0.1351
# FairSmote                      0.8103            1.5975  0.2516  0.1267
# FairwayRemover                 0.8065            1.6533  0.2906  0.1548
# HeterogeneousFOS               0.8141            1.5839  0.2667  0.1159
# LearningFairRepresentations    0.7429            2.4875  0.4794  0.3199
# Massaging                      0.8152            1.6286  0.2825  0.1487
# ReweighingClassifier           0.8179            1.5606  0.2586  0.1211
#
#                                 aod  true_negative_rate_difference  \
# method
# Baseline                     0.0881                        -0.0276
# DisparateImpactRemover       0.1258                        -0.0767
# FAWOS                        0.0881                        -0.0276
# FairBalanceClassifier        0.0684                        -0.0127
# FairMask                     0.0537                         0.0106
# FairOversampling             0.0720                        -0.0088
# FairSmote                    0.0396                         0.0476
# FairwayRemover               0.1040                        -0.0532
# HeterogeneousFOS             0.0673                        -0.0187
# LearningFairRepresentations  0.4250                        -0.5301
# Massaging                    0.0881                        -0.0276
# ReweighingClassifier         0.0606                         0.0000
#
#                              predictive_equality  accuracy_parity  \
# method
# Baseline                                  1.1409           1.1433
# DisparateImpactRemover                    1.3812           1.1456
# FAWOS                                     1.1409           1.1433
# FairBalanceClassifier                     1.0438           1.1322
# FairMask                                  0.9977           1.1339
# FairOversampling                          0.9912           1.1158
# FairSmote                                 0.9558           1.1374
# FairwayRemover                            1.2611           1.1416
# HeterogeneousFOS                          1.0743           1.1135
# LearningFairRepresentations               4.4039           1.1267
# Massaging                                 1.1409           1.1433
# ReweighingClassifier                      1.0067           1.1356
#
#                              equal_opportunity_ratio  \
# method
# Baseline                                      1.2179
# DisparateImpactRemover                        1.2450
# FAWOS                                         1.2179
# FairBalanceClassifier                         1.1748
# FairMask                                      1.1645
# FairOversampling                              1.2164
# FairSmote                                     1.1941
# FairwayRemover                                1.2280
# HeterogeneousFOS                              1.1673
# LearningFairRepresentations                   1.6653
# Massaging                                     1.2179
# ReweighingClassifier                          1.1725
#
#                              false_negative_rate_difference
# method
# Baseline                                            -0.1487
# DisparateImpactRemover                              -0.1749
# FAWOS                                               -0.1487
# FairBalanceClassifier                               -0.1241
# FairMask                                            -0.1179
# FairOversampling                                    -0.1351
# FairSmote                                           -0.1267
# FairwayRemover                                      -0.1548
# HeterogeneousFOS                                    -0.1159
# LearningFairRepresentations                         -0.3199
# Massaging                                           -0.1487
# ReweighingClassifier                                -0.1211
# --- Ricci ---
#                              accuracy  balanced_accuracy  precision  recall  \
# method
# Baseline                       0.8994             0.8994     0.8858  0.9045
# DisparateImpactRemover         0.8343             0.8338     0.8417  0.8125
# FAWOS                          0.8764             0.8800     0.8388  0.9504
# FairBalanceClassifier          0.9145             0.9158     0.8948  0.9371
# FairMask                       0.9120             0.9123     0.8975  0.9227
# FairOversampling               0.8891             0.8918     0.8548  0.9455
# FairSmote                      0.8827             0.8843     0.8567  0.9152
# FairwayRemover                 0.6544             0.6456     0.6218  0.4515
# HeterogeneousFOS               0.9148             0.9162     0.8896  0.9458
# LearningFairRepresentations    0.7659             0.7634     0.7901  0.6701
# Massaging                      0.7953             0.7951     0.7956  0.7848
# ReweighingClassifier           0.8956             0.8967     0.8786  0.9152
#
#                              f1_score  disparate_impact     spd     eod  \
# method
# Baseline                       0.8943            0.4402 -0.3745 -0.0571
# DisparateImpactRemover         0.8231            0.6001 -0.2861 -0.0496
# FAWOS                          0.8845            0.5788 -0.2945  0.0214
# FairBalanceClassifier          0.9133            0.5596 -0.2938  0.0365
# FairMask                       0.9092            0.4751 -0.3478  0.0012
# FairOversampling               0.8934            0.6061 -0.2740  0.0565
# FairSmote                      0.8822            0.5971 -0.2716  0.0142
# FairwayRemover                 0.4671            0.4942 -0.1876 -0.1254
# HeterogeneousFOS               0.9137            0.5624 -0.3032  0.0057
# LearningFairRepresentations    0.6920            0.3953 -0.3822 -0.2627
# Massaging                      0.7852            0.8295 -0.1126  0.0915
# ReweighingClassifier           0.8937            0.5963 -0.2714  0.0195
#
#                                 aod  true_negative_rate_difference  \
# method
# Baseline                    -0.1285                         0.1999
# DisparateImpactRemover      -0.0834                         0.1171
# FAWOS                       -0.0628                         0.1471
# FairBalanceClassifier       -0.0390                         0.1146
# FairMask                    -0.0931                         0.1874
# FairOversampling            -0.0317                         0.1200
# FairSmote                   -0.0436                         0.1014
# FairwayRemover              -0.1225                         0.1197
# HeterogeneousFOS            -0.0490                         0.1037
# LearningFairRepresentations -0.2723                         0.2818
# Massaging                    0.0830                        -0.0746
# ReweighingClassifier        -0.0313                         0.0820
#
#                              predictive_equality  accuracy_parity  \
# method
# Baseline                                  0.2208           1.0981
# DisparateImpactRemover                    0.4508           1.0637
# FAWOS                                     0.5971           1.0625
# FairBalanceClassifier                     0.4074           1.0865
# FairMask                                  0.2208           1.1194
# FairOversampling                          0.5701           1.0731
# FairSmote                                 0.3324           1.0730
# FairwayRemover                            0.7689           1.3476
# HeterogeneousFOS                          0.3574           1.0501
# LearningFairRepresentations               0.4925           1.2130
# Massaging                                 1.1409           1.0182
# ReweighingClassifier                      0.3991           1.0624
#
#                              equal_opportunity_ratio  \
# method
# Baseline                                      0.9423
# DisparateImpactRemover                        0.9983
# FAWOS                                         1.0307
# FairBalanceClassifier                         1.0517
# FairMask                                      1.0106
# FairOversampling                              1.0712
# FairSmote                                     1.0386
# FairwayRemover                                0.6749
# HeterogeneousFOS                              1.0150
# LearningFairRepresentations                   0.6701
# Massaging                                     1.1641
# ReweighingClassifier                          1.0383
#
#                              false_negative_rate_difference
# method
# Baseline                                             0.0571
# DisparateImpactRemover                               0.0496
# FAWOS                                               -0.0214
# FairBalanceClassifier                               -0.0365
# FairMask                                            -0.0012
# FairOversampling                                    -0.0565
# FairSmote                                           -0.0142
# FairwayRemover                                       0.1254
# HeterogeneousFOS                                    -0.0057
# LearningFairRepresentations                          0.2627
# Massaging                                           -0.0915
# ReweighingClassifier                                -0.0195

# %% [markdown]
# ## Tradeoff and ranking plots

# %%
report.plot_tradeoff(fairness_metric="spd", performance_metric="accuracy");
report.plot_ranking(classifier="LogReg");
